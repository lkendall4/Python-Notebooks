# %%
# %matplotlib inline
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_values = pd.read_csv('C:/Users/student/Documents/earthquake/train_values.csv', index_col='building_id')
train_labels = pd.read_csv('C:/Users/student/Documents/earthquake/train_labels.csv', index_col='building_id')

# %%
train_values.dtypes
# Out:
# geo_level_1_id                             int64
# geo_level_2_id                             int64
# geo_level_3_id                             int64
# count_floors_pre_eq                        int64
# age                                        int64
# area_percentage                            int64
# height_percentage                          int64
# land_surface_condition                    object
# foundation_type                           object
# roof_type                                 object
# ground_floor_type                         object
# other_floor_type                          object
# position                                  object
# plan_configuration                        object
# has_superstructure_adobe_mud               int64
# has_superstructure_mud_mortar_stone        int64
# has_superstructure_stone_flag              int64
# has_superstructure_cement_mortar_stone     int64
# has_superstructure_mud_mortar_brick        int64
# ...

# %% [markdown]
# **Explore the Data**

# %%
(train_labels.damage_grade
             .value_counts()
             .sort_index()
             .plot.bar(title="Number of Buildings with Each Damage Grade"))

# %%
selected_features = ['foundation_type', 
                     'area_percentage', 
                     'height_percentage',
                     'count_floors_pre_eq',
                     'land_surface_condition',
                     'has_superstructure_cement_mortar_stone']

train_values_subset = train_values[selected_features]

# %%
sns.pairplot(train_values_subset.join(train_labels), 
             hue='damage_grade')
# Out:
# C:\Users\student\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\Users\student\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\Users\student\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\Users\student\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
